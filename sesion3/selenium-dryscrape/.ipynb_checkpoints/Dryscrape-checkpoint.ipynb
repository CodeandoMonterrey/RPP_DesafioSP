# %%
import dryscrape

# %%
#http://www.cns.gob.mx/extraviadosWeb/portals/extraviados.portal
sess = dryscrape.Session(base_url = "http://www.cns.gob.mx/extraviadosWeb/portals/")

# %%
sess.visit("extraviados.portal")

# %%
sess.body()
# Out:
# '<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html><head>\n\n\n<title>Extraviados</title><link rel="stylesheet" type="text/css" href="/extraviadosWeb/framework/skins/extraviadosPortal/body.css"><link rel="stylesheet" type="text/css" href="/extraviadosWeb/framework/skins/extraviadosPortal/book.css"><link rel="stylesheet" type="text/css" href="/extraviadosWeb/framework/skins/extraviadosPortal/button.css"><link rel="stylesheet" type="text/css" href="/extraviadosWeb/framework/skins/extraviadosPortal/form.css"><link rel="stylesheet" type="text/css" href="/extraviadosWeb/framework/skins/extraviadosPortal/layout.css"><link rel="stylesheet" type="text/css" href="/extraviadosWeb/framework/skins/extraviadosPortal/portlet.css"><link rel="stylesheet" type="text/css" href="/extraviadosWeb/framework/skins/extraviadosPortal/window.css"><script src="/extraviadosWeb/framework/skins/extraviadosPortal/js/delete.js" type="text/javascript"></script><script src="float.js" type="text/javascript"></script><script src="/extraviadosWeb/framework/skins/extraviadosPortal/js/menu.js" type="text/javascript"></script><script src="/extraviadosWeb/framework/skins/extraviadosPortal/js/skin.js" type="text/javascript"></script><script src="/extraviadosWeb/framework/skins/extraviadosPortal/js/extraviados.js" type="text/javascript"></script>\n\n\n\n\t</head>\n\n\n\n\n\n<body>\n<div class="bea-portal-body-content">\n</div>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<script language="JavaScript" type="text/javascript">\n\n            iluminada = new Image(84,34)\n            iluminada.src = "/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/aguascalientes.gif"\n            apagada = new Image(84,34)\n            apagada.src = "/extraviadosWeb/framework/skins/extraviadosPortal/images/aguascalientes.gif" \n    \n    \n            function cAmbiaOver(imagen){\n                //alert(imagen);\n                switch (imagen){\n                    case "imagen_00": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/aguascalientes.gif";break;\n                    case "imagen_01": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Baja_California.gif";break;\n                    case "imagen_02": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Baja_California_Sur.gif";break;\n                    case "imagen_03": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Campeche.gif";break;\n                    case "imagen_04": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Chiapas.gif";break;\n                    case "imagen_05": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Chihuahua.gif";break;\n                    case "imagen_06": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Coahuila.gif";break;\n                    case "imagen_07": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Colima.gif";break;\n                    case "imagen_08": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Distrito_Federal.gif";break;\n                    case "imagen_09": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Durango.gif";break;\n                    case "imagen_10": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/Estado_Mexico.gif";break;\n                    case "imagen_11": document.getElementById(imagen).src="/extraviadosWeb/framework/skins/extraviadosPortal/images/rollover/guanajuato.gif";break;\n                    case "imagen_12":  ...

# %%
sess.render("output_dryscrape_1.png")

# %%
search_term = "a"

# %%
q = sess.at_xpath('//*[@name="Extra_FlowController_1{actionForm.paterno}"]')
q.set(search_term)
q.form().submit()

# %%
sess.render("output_dryscrape_2.png")

# %%
from bs4 import BeautifulSoup
